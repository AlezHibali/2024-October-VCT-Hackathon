# %%
import requests
import re
import os
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import time
from bs4 import BeautifulSoup

# %%
# Function to create a session with retries and timeout
def create_session():
    session = requests.Session()
    retries = Retry(total=5,  # Number of retries
                    backoff_factor=0.3,  # Wait between retries
                    status_forcelist=[500, 502, 503, 504])  # Retry on specific HTTP status codes
    session.mount('https://', HTTPAdapter(max_retries=retries))
    return session

# Function to get the HTML content of a webpage with retries and timeout
def get_html(url, session):
    try:
        response = session.get(url, timeout=10)
        if response.status_code == 200:
            return response.text
    except requests.exceptions.RequestException as e:
        print(f"Error fetching {url}: {e}")
    return None

# Function to extract individual article links from the news page using regex
def extract_article_links(news_page_html):
    # Regex pattern to find article links in the form of '/news/xxxxxx-title'
    pattern = re.compile(r'href="(/[\d]+/[^"]+)"')
    article_links = pattern.findall(news_page_html)
    full_links = ['https://www.vlr.gg' + link for link in article_links]
    return full_links

# Function to extract content from individual article pages using string manipulation
def extract_article_content(article_html):
    # Extract title using regex or manual string operations
    title_start = article_html.find('<h1 class="wf-title">')
    title_end = article_html.find('</h1>', title_start)
    title = article_html[title_start + len('<h1 class="wf-title">'):title_end].strip()

    # Extract the date using a similar approach
    date_start = article_html.find('class="article-header__date">')
    date_end = article_html.find('</div>', date_start)
    date = article_html[date_start + len('class="article-header__date">'):date_end].strip()

    # Extract the main content (this might need adjusting based on actual content structure)
    content_start = article_html.find('<div class="article-content">')
    content_end = article_html.find('</div>', content_start)
    content = article_html[content_start + len('<div class="article-content">'):content_end].strip()

    return title, date, content

# Function to sanitize the file name by replacing special characters
def sanitize_filename(filename):
    # Replace special characters like : and / with underscores or safe characters
    return re.sub(r'[<>:"/\\|?*]', '_', filename)

# Function to save article content to a text file, ensuring valid data
def save_article_to_file(title, date, content, article_url, folder_path='articles'):
    if not title or not content or len(content) < 100:  # Check if the title or content is valid and reasonable
        print(f"Skipping saving article from {article_url} due to missing or incomplete content.")
        return

    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    # Sanitize the title to avoid filesystem issues (replace special characters)
    file_name = sanitize_filename(title) if title else article_url.split('/')[-1]
    file_name = file_name[:100]  # Limit the filename to avoid filesystem issues
    file_path = os.path.join(folder_path, file_name + '.txt')

    # Write the article content to the file
    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(f"Title: {title}\n")
        file.write(f"Date: {date}\n")
        file.write(f"\n{content}")
    print(f"Saved article: {file_name}")

# Main function to crawl multiple pages of the news site and save articles
def crawl_vlr_news(max_pages=5):
    base_url = 'https://www.vlr.gg/news/?page='
    session = create_session()

    for page in range(1, max_pages + 1):
        news_page_url = base_url + str(page)
        news_page_html = get_html(news_page_url, session)

        if news_page_html:
            article_links = extract_article_links(news_page_html)

            if not article_links:
                print(f"No more articles found on page {page}. Stopping.")
                break

            for article_url in article_links:
                article_html = get_html(article_url, session)
                if article_html:
                    title, date, content = extract_article_content(article_html)
                    if title and content:
                        save_article_to_file(title, date, content, article_url)
                else:
                    print(f"Failed to retrieve article: {article_url}")

                time.sleep(1)  # Add a small delay between requests to avoid overwhelming the server
        else:
            print(f"Failed to retrieve page: {news_page_url}")

# %%
crawl_vlr_news(max_pages=5)
# Out:
# Saved article: Team Liquid announces kamo, LohaN, yaotziN
# Saved article: DFM announce full 2025 roster
# Saved article: JDG Esports signs sword9 and hypnotizing
# Saved article: Wolves Esports signs Lysoar and Fayde
# Saved article: Gen.G re-signs Munchkin
# Saved article: T1 adds BuZz
# Saved article: Chet suspended through Masters Bangkok
# Saved article: BBL Esports bids farewell to QutionerX, Brave, and reazy
# Saved article: T1 picks up Meteor
# Saved article: LEVIATÁN summons Demon1
# Saved article: Sentinels adds Reduxx as their sixth
# Saved article: DRX signs HYUNMIN and freeing
# Saved article: NRG completes roster, signs mada, Verno, and bonkar
# Saved article: BBL Esports signs LewN
# Saved article: RRQ round off roster with Kush and Warbirds
# Saved article: JDG parts ways with Anaks and Billyo
# Saved article: NRG releases Demon1
# Saved article: T1 signs Sylvan, Indigo, and CheongGak
# Saved article: BOOM Esports part ways with ZesBeeW and Meow
# Saved article: Cloud9 signs Rossy and v1c
# Saved article: 100 Thieves pick up zander
# Saved article: Flex1n splits with Bilbili Gaming
# Saved article: Talon Esports announces departures of Patiphan and b0i
# Saved article: Cloud9 announces departures of runi and Vanity
# Saved article: runneR, Gorilla, temoc, Placido part with Team Vitality
# Saved article: Sentinels announce N4RRATE and bang
# Saved article: jawgemo signs with G2 Esports
# Saved article: DetonatioN FocusMe releases Medusa, Anthem, neth, Astell
# Saved article: DRX part with BuZz, Foxy9, and BeYN
# Saved article: Gen.G announce free agency of Munchkin, Lakia, and Meteor
# Saved article: jawgemo and Evil Geniuses part ways
# Saved article: sScary and LEGIJA announce free agency
# Saved article: Riot removes BLEED from VCT Pacific, BOOM promoted
# Saved article: 100 Thieves release bang
# Saved article: ShadoW becomes restricted free agent
# Saved article: MEDUSA and Anthem to explore options outside of DFM
# Saved article: Cloud9 qualifies to Red Bull Home Ground Main Event
# Saved article: Undefeated Sin Prisa Gaming wins Ascension Pacific
# Saved article: Zellsis_ _We both know that he ain't gonna be yelling s--t_
# Saved article: FURIA allows nzr to explore options
# Saved article: G2 Esports release icy
# Saved article: M80 parts ways with entire Valorant roster
# Saved article: BBL allows pAura to explore options
# Saved article: Kr1stal departs Xi Lai Gaming
# Saved article: 2Game Esports lift Americas Ascension trophy
# Saved article: Xi Lai Gaming lifts Ascension China
# Saved article: FNATIC adds Milan as assistant coach
# Saved article: Karmine Corp parts ways with MAGNUM
# Saved article: Acend pull out of Valorant
# Saved article: Apeks win VCT EMEA Ascension
# Saved article: Sacy announces retirement
# Saved article: TenZ retires from competitive play
# Saved article: sh1n to explore options outside of Karmine Corp
# Saved article: Team Liquid parts with head coach eMIL
# Saved article: tomaszy announces restricted free agency
# Saved article: KRÜ to continue without heat
# Saved article: Assistant coach DrewSpark departs Sentinels
# Saved article: ZETA DIVISION release hiroronn and yuran
# Saved article: Moist x Shopify roster to explore options
# Saved article: GIANTX Fit1nho, hoody, Famsii become free agents
# Saved article: Mini departs FNATIC
# Saved article: LOUD and Saadhak to part ways
# Saved article: SUYGETSU to explore options outside of NAVI
# Saved article: Leviatán allows Mazino to explore options
# Saved article: crashies departs NRG as free agent
# Saved article: KOI starxo enters free agency
# Saved article: hiro and FNATIC part ways
# Saved article: Ardiis enters restricted free agency
# Saved article: TL Jamppi, Mistic, and Enzo enter restricted free agency
# Saved article: NAVI allows Zyppan to explore options
# Saved article: Oxygen Esports disbands Valorant roster
# Saved article: Riot announces finalized details for VCT Ascension Pacific
# Saved article: M8 TaKaS to explore options for 2025
# Saved article: Derke enters restricted free agency
# Saved article: ZETA Division’s Laz announces retirement
# Saved article: EDward Gaming conquer Champions 2024 in historic win for China
# Saved article: Team Heretics topple Leviátan, advance to Champions 2024 grand final
# Saved article: Team Heretics beat Sentinels, will face Leviátan in lower finals
# Saved article: EDward Gaming take down Leviátan, advance to China's first-ever international grand final
# Saved article: VLR Rating 2.0 Update
# Saved article: Global Esports roster become Restricted Free Agents
# Saved article: Riot announces VCT 2025 details
# Saved article: Secret part ways with NDG
# Saved article: pl1xx leaves Wolves Esports after one season
# Saved article: Team Heretics reach top four with 2-1 over DRX
# Saved article: Sentinels go the distance, eliminate FNATIC
# Saved article: Leviátan topple Team Heretics to secure upper finals
# Saved article: EDward Gaming push past Sentinels, progress to top three
# Saved article: FNATIC dominate G2 and survive first Champions elimination bout
# Saved article: DRX sweep Trace Esports in first lower bracket match of Champions
# Saved article: Team Heretics continue winstreak with 2-0 over FNATIC
# Saved article: Leviátan sweep G2 in all-Americas rematch, advance to upper semis
# Saved article: EDG extend winstreak over Trace with Champions quarterfinals win
# Saved article: Sentinels send DRX to lower bracket with 2-0 sweep
# Saved article: Toast speaks on Disguised reaching Ascension in year two
# Saved article: BLEED announce roster overhaul, bench four players
# Saved article: Patch 9.03 brings quality-of-life ability updates
# Saved article: T1 parts ways with coach Daeda
# Saved article: Valorant OFF__SEASON 2024 events announced
# Saved article: EDG coach Muggle expresses relief after qualifying for Champions playoffs in press conference
# Saved article: f0rsakeN elaborates on difficulty facing EDG in press conference
# Saved article: Champions playoffs matches revealed
# Saved article: EDG round out playoffs with 2-1 over Paper Rex
# Saved article: Sayf speaks on key takeaways and lessons from 2024 in press conference
# Saved article: trexx_ _I thought the veto was very good for us_
# Saved article: Leviatán overcome Team Vitality to claim playoff berth
# Saved article: vanity's second Cloud9 stint comes to an end
# Saved article: Boaster revels on team qualities heading into Champions playoffs in press conference
# Saved article: KRÜ talk on upsides to 2024 season despite early Champions exit in press conference
# Saved article: Fnatic avenge the past, qualify to playoffs
# Saved article: Zellsis pokes fun at haters following Gen.G elimination in press conference
# Saved article: t3xture reviews Gen.G's 2024 season in press conference
# Saved article: Sentinels survive group of death, eliminate Gen.G
# Saved article: cNed admits regression from Shanghai following Champions elimination in press conference
# Saved article: f0rsakeN reveals thoughts on upcoming decider against EDG in press conference
# Saved article: alecks_ _I just let them ride the high_
# Saved article: Paper Rex return to form in 2-0 against FUT
# Saved article: Team Vitality sweep, eliminate Talon Esports
# Saved article: Riot announces changes to VCT Ascension Pacific
# Saved article: DarkZero part ways with former Turtle Troop roster
# Saved article: Bilibili Gaming looks back on 2024 season in press conference
# Saved article: TenZ speaks on bouncing back heading into FPX matchup in press conference
# Saved article: nephh_ _Our performance wasn't up to standard_
# Saved article: KRÜ Esports stay alive with 2-0 over Bilibili
# Saved article: Sentinels eliminate FPX in dominant 2-0 sweep
# Saved article: 100T say goodbye to Mikes
# Saved article: ZmjjKK reveals major shortcomings against G2 in press conference
# Saved article: G2 speaks on narrow victory over EDG in press conference
# Saved article: G2 make playoffs after 2-1 against EDG
# Saved article: Leviatán coach Itopata concedes to issues against Trace in press conference
# Saved article: C0M_ _We just have to go back to the drawing board_
# Saved article: Trace Esports upset Leviatán to secure playoff spot at Champions 2024
# Saved article: Chronicle_ _I think we were clueless_
# Saved article: DRX claim first playoff berth of Group A
# Saved article: Munchkin acknowledges factors leading to upset loss against Heretics in press conference
# Saved article: Boo backs up Gen.G's performance following Heretics victory in press conference
# Saved article: benjyfishy_ _One of my goals was to have my family watch me at an international event_
# Saved article: Team Heretics exact revenge on Gen.G, qualify for quarterfinals
# Saved article: EDG S1Mon reflects on international debut against FUT in press conference
# Saved article: MrFaliN pinpoints loss to EDG on micro mistakes in press conference
# Saved article: EDG begin redemption arc against FUT
# Saved article: d4v41_ _We weren't synchronized enough to stop their retakes_
# Saved article: alecks addresses mistakes made against G2 in press conference
# Saved article: G2 Esports walk over Paper Rex with 2-0 win
# Saved article: Gorilla_ _Trace aren't underdogs at all here_
# Saved article: Sayf keeps Vitality's spirits held high in press conference despite loss
# Saved article: Trace put China on the board at Champions
# Saved article: FrosT_ _The biggest reason we lost is because we were too nervous_
# Saved article: Talon's FrosT hammers in on critical errors made against Leviatán in team press conference
# Saved article: Leviatán defeat Talon Esports 2-0 to begin their Champions 2024 campaign

# %%
def clean_html_content(html_content):
    # Parse the HTML with Beautiful Soup
    soup = BeautifulSoup(html_content, "html.parser")

    # Define a regular expression pattern to identify the span with a specific class or attributes
    pattern = re.compile(r'\bwf-hover-card\b')

    # Find all spans with the pattern that matches the target
    for span in soup.find_all("span", class_=pattern):
        span.decompose()
        
    # Get the modified HTML
    modified_html = str(soup)
    
    return modified_html
    
# Function to extract title, author, date, and article content from the provided HTML
def extract_article_details(file_path):
    # Read the content of the file
    with open(file_path, 'r', encoding='utf-8') as file:
        html_content = file.read()
        
    # Extract title
    title_match = re.search(r'<h1 class="wf-title">\s*(.*?)\s*</h1>', html_content)
    title = title_match.group(1).strip() if title_match else "Unknown Title"
    
    # Extract author
    author_match = re.search(r'class="article-meta-author".*?>(.*?)</a>', html_content)
    author = author_match.group(1).strip() if author_match else "Unknown Author"

    # Extract date
    date_match = re.search(r'<span class="js-date-toggle".*?title="(.*?)">', html_content)
    date = date_match.group(1).strip() if date_match else "Unknown Date"
    
    html_content = clean_html_content(html_content)
        
    html_content = re.split(r'<div class="wf-label comments-label"', html_content, 1)[0]
    # Extract all content inside <p> tags
    paragraphs = re.findall(r'<p>(.*?)</p>', html_content, re.DOTALL)
    content = "\n\n".join([re.sub(r'<.*?>', '', p).strip() for p in paragraphs])
    # Remove inline tags that are unnecessary
    content = re.sub(r'<.*?>', '', content)
    # Remove excess whitespace and line breaks
    # Step 1: Remove spaces or tabs between line breaks
#    content = re.sub(r'\n\s*\n', '\n', content)

    # Step 2: Replace multiple consecutive line breaks with a single line break
#    content = re.sub(r'\n+', '\n', content).strip()
    #content = re.sub(r'\s+', ' ', content).strip()
    return title, author, date, content

# Function to extract title, author, date, and all content inside <p> tags, stopping before a specific div
def extract_article_details(file_path):
    # Read the content of the file
    with open(file_path, 'r', encoding='utf-8') as file:
        html_content = file.read()
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Define a regular expression pattern to identify the span with a specific class or attributes
    pattern = re.compile(r'\bwf-hover-card\b')

    # Find all spans with the pattern that matches the target
    for span in soup.find_all("span", class_=pattern):
        span.decompose()

    pattern = re.compile(r'\bpost-container\b')

    # Find all spans with the pattern that matches the target
    for span in soup.find_all("div", class_=pattern):
        span.decompose()
        
    # Extract the title, author, date, and content
    title = soup.find('title').text.strip()
    author = soup.find('a', class_='article-meta-author').text.strip()
    date = soup.find('span', class_='js-date-toggle').get('title').strip()
    content = "\n".join(p.text for p in soup.find_all(['p','li']))

    content = re.sub(r'\n+', '\n', content).strip()
    content = re.sub(r'\s+', ' ', content).strip()
    return title, author, date, content

# Example function to display extracted details
def display_article_details(title, author, date, content):
    display = ''
    display+=f"Title: {title}\n"
    display+=f"Author: {author}\n"
    display+=f"Date: {date}\n"
    display+=f"\nContent:\n{content}\n"
    return display

def process_folder(input_folder, output_folder):
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Iterate over all .txt files in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith('.txt'):
            input_file_path = os.path.join(input_folder, filename)
            output_file_path = os.path.join(output_folder, filename)

            # Extract article content
            title, author, date, content = extract_article_details(input_file_path)
            article_details = display_article_details(title, author, date, content)
            # Save the extracted content to the output file
            with open(output_file_path, 'w', encoding='utf-8') as output_file:
                output_file.write(article_details)
            
            print(f'Processed: {filename}')

# Example usage:
input_folder = 'articles/original'
output_folder = 'articles/fixed'

process_folder(input_folder, output_folder)
# Out:
# Processed: 100 Thieves pick up zander.txt
# Processed: 100 Thieves release bang.txt
# Processed: 100T say goodbye to Mikes.txt
# Processed: 2Game Esports lift Americas Ascension trophy.txt
# Processed: Acend pull out of Valorant.txt
# Processed: alecks addresses mistakes made against G2 in press conference.txt
# Processed: alecks_ _I just let them ride the high_.txt
# Processed: Apeks win VCT EMEA Ascension.txt
# Processed: Ardiis enters restricted free agency.txt
# Processed: Assistant coach DrewSpark departs Sentinels.txt
# Processed: BBL allows pAura to explore options.txt
# Processed: BBL Esports bids farewell to QutionerX, Brave, and reazy.txt
# Processed: BBL Esports signs LewN.txt
# Processed: benjyfishy_ _One of my goals was to have my family watch me at an international event_.txt
# Processed: Bilibili Gaming looks back on 2024 season in press conference.txt
# Processed: BLEED announce roster overhaul, bench four players.txt
# Processed: Boaster revels on team qualities heading into Champions playoffs in press conference.txt
# Processed: Boo backs up Gen.G's performance following Heretics victory in press conference.txt
# Processed: BOOM Esports part ways with ZesBeeW and Meow.txt
# Processed: C0M_ _We just have to go back to the drawing board_.txt
# Processed: Champions playoffs matches revealed.txt
# Processed: Chet suspended through Masters Bangkok.txt
# Processed: Chronicle_ _I think we were clueless_.txt
# Processed: Cloud9 announces departures of runi and Vanity.txt
# Processed: Cloud9 qualifies to Red Bull Home Ground Main Event.txt
# Processed: Cloud9 signs Rossy and v1c.txt
# Processed: cNed admits regression from Shanghai following Champions elimination in press conference.txt
# Processed: crashies departs NRG as free agent.txt
# Processed: d4v41_ _We weren't synchronized enough to stop their retakes_.txt
# Processed: DarkZero part ways with former Turtle Troop roster.txt
# Processed: Derke enters restricted free agency.txt
# Processed: DetonatioN FocusMe releases Medusa, Anthem, neth, Astell.txt
# Processed: DFM announce full 2025 roster.txt
# Processed: DRX claim first playoff berth of Group A.txt
# Processed: DRX part with BuZz, Foxy9, and BeYN.txt
# Processed: DRX signs HYUNMIN and freeing.txt
# Processed: DRX sweep Trace Esports in first lower bracket match of Champions.txt
# Processed: EDG begin redemption arc against FUT.txt
# Processed: EDG coach Muggle expresses relief after qualifying for Champions playoffs in press conference.txt
# Processed: EDG extend winstreak over Trace with Champions quarterfinals win.txt
# Processed: EDG round out playoffs with 2-1 over Paper Rex.txt
# Processed: EDG S1Mon reflects on international debut against FUT in press conference.txt
# Processed: EDward Gaming conquer Champions 2024 in historic win for China.txt
# Processed: EDward Gaming push past Sentinels, progress to top three.txt
# Processed: EDward Gaming take down Leviátan, advance to China's first-ever international grand final.txt
# Processed: f0rsakeN elaborates on difficulty facing EDG in press conference.txt
# Processed: f0rsakeN reveals thoughts on upcoming decider against EDG in press conference.txt
# Processed: Flex1n splits with Bilbili Gaming.txt
# Processed: FNATIC adds Milan as assistant coach.txt
# Processed: Fnatic avenge the past, qualify to playoffs.txt
# Processed: FNATIC dominate G2 and survive first Champions elimination bout.txt
# Processed: FrosT_ _The biggest reason we lost is because we were too nervous_.txt
# Processed: FURIA allows nzr to explore options.txt
# Processed: G2 Esports release icy.txt
# Processed: G2 Esports walk over Paper Rex with 2-0 win.txt
# Processed: G2 make playoffs after 2-1 against EDG.txt
# Processed: G2 speaks on narrow victory over EDG in press conference.txt
# Processed: Gen.G announce free agency of Munchkin, Lakia, and Meteor.txt
# Processed: Gen.G re-signs Munchkin.txt
# Processed: GIANTX Fit1nho, hoody, Famsii become free agents.txt
# Processed: Global Esports roster become Restricted Free Agents.txt
# Processed: Gorilla_ _Trace aren't underdogs at all here_.txt
# Processed: hiro and FNATIC part ways.txt
# Processed: jawgemo and Evil Geniuses part ways.txt
# Processed: jawgemo signs with G2 Esports.txt
# Processed: JDG Esports signs sword9 and hypnotizing.txt
# Processed: JDG parts ways with Anaks and Billyo.txt
# Processed: Karmine Corp parts ways with MAGNUM.txt
# Processed: KOI starxo enters free agency.txt
# Processed: Kr1stal departs Xi Lai Gaming.txt
# Processed: KRÜ Esports stay alive with 2-0 over Bilibili.txt
# Processed: KRÜ talk on upsides to 2024 season despite early Champions exit in press conference.txt
# Processed: KRÜ to continue without heat.txt
# Processed: Leviatán allows Mazino to explore options.txt
# Processed: Leviatán coach Itopata concedes to issues against Trace in press conference.txt
# Processed: Leviatán defeat Talon Esports 2-0 to begin their Champions 2024 campaign.txt
# Processed: Leviatán overcome Team Vitality to claim playoff berth.txt
# Processed: LEVIATÁN summons Demon1.txt
# Processed: Leviátan sweep G2 in all-Americas rematch, advance to upper semis.txt
# Processed: Leviátan topple Team Heretics to secure upper finals.txt
# Processed: LOUD and Saadhak to part ways.txt
# Processed: M8 TaKaS to explore options for 2025.txt
# Processed: M80 parts ways with entire Valorant roster.txt
# Processed: MEDUSA and Anthem to explore options outside of DFM.txt
# Processed: Mini departs FNATIC.txt
# Processed: Moist x Shopify roster to explore options.txt
# Processed: MrFaliN pinpoints loss to EDG on micro mistakes in press conference.txt
# Processed: Munchkin acknowledges factors leading to upset loss against Heretics in press conference.txt
# Processed: NAVI allows Zyppan to explore options.txt
# Processed: nephh_ _Our performance wasn't up to standard_.txt
# Processed: NRG completes roster, signs mada, Verno, and bonkar.txt
# Processed: NRG releases Demon1.txt
# Processed: Oxygen Esports disbands Valorant roster.txt
# Processed: Paper Rex return to form in 2-0 against FUT.txt
# Processed: Patch 9.03 brings quality-of-life ability updates.txt
# Processed: pl1xx leaves Wolves Esports after one season.txt
# Processed: Riot announces changes to VCT Ascension Pacific.txt
# Processed: Riot announces finalized details for VCT Ascension Pacific.txt
# Processed: Riot announces VCT 2025 details.txt
# Processed: Riot removes BLEED from VCT Pacific, BOOM promoted.txt
# Processed: RRQ round off roster with Kush and Warbirds.txt
# Processed: runneR, Gorilla, temoc, Placido part with Team Vitality.txt
# Processed: Sacy announces retirement.txt
# Processed: Sayf keeps Vitality's spirits held high in press conference despite loss.txt
# Processed: Sayf speaks on key takeaways and lessons from 2024 in press conference.txt
# Processed: Secret part ways with NDG.txt
# Processed: Sentinels adds Reduxx as their sixth.txt
# Processed: Sentinels announce N4RRATE and bang.txt
# Processed: Sentinels eliminate FPX in dominant 2-0 sweep.txt
# Processed: Sentinels go the distance, eliminate FNATIC.txt
# Processed: Sentinels send DRX to lower bracket with 2-0 sweep.txt
# Processed: Sentinels survive group of death, eliminate Gen.G.txt
# Processed: sh1n to explore options outside of Karmine Corp.txt
# Processed: ShadoW becomes restricted free agent.txt
# Processed: sScary and LEGIJA announce free agency.txt
# Processed: SUYGETSU to explore options outside of NAVI.txt
# Processed: T1 adds BuZz.txt
# Processed: T1 parts ways with coach Daeda.txt
# Processed: T1 picks up Meteor.txt
# Processed: T1 signs Sylvan, Indigo, and CheongGak.txt
# Processed: t3xture reviews Gen.G's 2024 season in press conference.txt
# Processed: Talon Esports announces departures of Patiphan and b0i.txt
# Processed: Talon's FrosT hammers in on critical errors made against Leviatán in team press conference.txt
# Processed: Team Heretics beat Sentinels, will face Leviátan in lower finals.txt
# Processed: Team Heretics continue winstreak with 2-0 over FNATIC.txt
# Processed: Team Heretics exact revenge on Gen.G, qualify for quarterfinals.txt
# Processed: Team Heretics reach top four with 2-1 over DRX.txt
# Processed: Team Heretics topple Leviátan, advance to Champions 2024 grand final.txt
# Processed: Team Liquid announces kamo, LohaN, yaotziN.txt
# Processed: Team Liquid parts with head coach eMIL.txt
# Processed: Team Vitality sweep, eliminate Talon Esports.txt
# Processed: TenZ retires from competitive play.txt
# Processed: TenZ speaks on bouncing back heading into FPX matchup in press conference.txt
# Processed: TL Jamppi, Mistic, and Enzo enter restricted free agency.txt
# Processed: Toast speaks on Disguised reaching Ascension in year two.txt
# Processed: tomaszy announces restricted free agency.txt
# Processed: Trace Esports upset Leviatán to secure playoff spot at Champions 2024.txt
# Processed: Trace put China on the board at Champions.txt
# Processed: trexx_ _I thought the veto was very good for us_.txt
# Processed: Undefeated Sin Prisa Gaming wins Ascension Pacific.txt
# Processed: Valorant OFF__SEASON 2024 events announced.txt
# Processed: vanity's second Cloud9 stint comes to an end.txt
# Processed: VLR Rating 2.0 Update.txt
# Processed: Wolves Esports signs Lysoar and Fayde.txt
# Processed: Xi Lai Gaming lifts Ascension China.txt
# Processed: Zellsis pokes fun at haters following Gen.G elimination in press conference.txt
# Processed: Zellsis_ _We both know that he ain't gonna be yelling s--t_.txt
# Processed: ZETA DIVISION release hiroronn and yuran.txt
# Processed: ZETA Division’s Laz announces retirement.txt
# Processed: ZmjjKK reveals major shortcomings against G2 in press conference.txt

# %%
# Example usage:
input_folder = 'articles'
output_folder = 'articles/original'

def temper(input_folder, output_folder):
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Iterate over all .txt files in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith('.txt'):
            input_file_path = os.path.join(input_folder, filename)
            output_file_path = os.path.join(output_folder, filename)

            with open(input_file_path, 'r', encoding='utf-8') as file:
                html_content = file.read()
            html_content = html_content[html_content.index("<head>"):]
            with open(output_file_path, 'w', encoding='utf-8') as output_file:
                output_file.write(html_content)
            
            print(f'Processed: {filename}')
            
temper(input_folder, output_folder)
# Out:
# Processed: 100 Thieves pick up zander.txt
# Processed: 100 Thieves release bang.txt
# Processed: 100T say goodbye to Mikes.txt
# Processed: 2Game Esports lift Americas Ascension trophy.txt
# Processed: Acend pull out of Valorant.txt
# Processed: alecks addresses mistakes made against G2 in press conference.txt
# Processed: alecks_ _I just let them ride the high_.txt
# Processed: Apeks win VCT EMEA Ascension.txt
# Processed: Ardiis enters restricted free agency.txt
# Processed: Assistant coach DrewSpark departs Sentinels.txt
# Processed: BBL allows pAura to explore options.txt
# Processed: BBL Esports bids farewell to QutionerX, Brave, and reazy.txt
# Processed: BBL Esports signs LewN.txt
# Processed: benjyfishy_ _One of my goals was to have my family watch me at an international event_.txt
# Processed: Bilibili Gaming looks back on 2024 season in press conference.txt
# Processed: BLEED announce roster overhaul, bench four players.txt
# Processed: Boaster revels on team qualities heading into Champions playoffs in press conference.txt
# Processed: Boo backs up Gen.G's performance following Heretics victory in press conference.txt
# Processed: BOOM Esports part ways with ZesBeeW and Meow.txt
# Processed: C0M_ _We just have to go back to the drawing board_.txt
# Processed: Champions playoffs matches revealed.txt
# Processed: Chet suspended through Masters Bangkok.txt
# Processed: Chronicle_ _I think we were clueless_.txt
# Processed: Cloud9 announces departures of runi and Vanity.txt
# Processed: Cloud9 qualifies to Red Bull Home Ground Main Event.txt
# Processed: Cloud9 signs Rossy and v1c.txt
# Processed: cNed admits regression from Shanghai following Champions elimination in press conference.txt
# Processed: crashies departs NRG as free agent.txt
# Processed: d4v41_ _We weren't synchronized enough to stop their retakes_.txt
# Processed: DarkZero part ways with former Turtle Troop roster.txt
# Processed: Derke enters restricted free agency.txt
# Processed: DetonatioN FocusMe releases Medusa, Anthem, neth, Astell.txt
# Processed: DFM announce full 2025 roster.txt
# Processed: DRX claim first playoff berth of Group A.txt
# Processed: DRX part with BuZz, Foxy9, and BeYN.txt
# Processed: DRX signs HYUNMIN and freeing.txt
# Processed: DRX sweep Trace Esports in first lower bracket match of Champions.txt
# Processed: EDG begin redemption arc against FUT.txt
# Processed: EDG coach Muggle expresses relief after qualifying for Champions playoffs in press conference.txt
# Processed: EDG extend winstreak over Trace with Champions quarterfinals win.txt
# Processed: EDG round out playoffs with 2-1 over Paper Rex.txt
# Processed: EDG S1Mon reflects on international debut against FUT in press conference.txt
# Processed: EDward Gaming conquer Champions 2024 in historic win for China.txt
# Processed: EDward Gaming push past Sentinels, progress to top three.txt
# Processed: EDward Gaming take down Leviátan, advance to China's first-ever international grand final.txt
# Processed: f0rsakeN elaborates on difficulty facing EDG in press conference.txt
# Processed: f0rsakeN reveals thoughts on upcoming decider against EDG in press conference.txt
# Processed: Flex1n splits with Bilbili Gaming.txt
# Processed: FNATIC adds Milan as assistant coach.txt
# Processed: Fnatic avenge the past, qualify to playoffs.txt
# Processed: FNATIC dominate G2 and survive first Champions elimination bout.txt
# Processed: FrosT_ _The biggest reason we lost is because we were too nervous_.txt
# Processed: FURIA allows nzr to explore options.txt
# Processed: G2 Esports release icy.txt
# Processed: G2 Esports walk over Paper Rex with 2-0 win.txt
# Processed: G2 make playoffs after 2-1 against EDG.txt
# Processed: G2 speaks on narrow victory over EDG in press conference.txt
# Processed: Gen.G announce free agency of Munchkin, Lakia, and Meteor.txt
# Processed: Gen.G re-signs Munchkin.txt
# Processed: GIANTX Fit1nho, hoody, Famsii become free agents.txt
# Processed: Global Esports roster become Restricted Free Agents.txt
# Processed: Gorilla_ _Trace aren't underdogs at all here_.txt
# Processed: hiro and FNATIC part ways.txt
# Processed: jawgemo and Evil Geniuses part ways.txt
# Processed: jawgemo signs with G2 Esports.txt
# Processed: JDG Esports signs sword9 and hypnotizing.txt
# Processed: JDG parts ways with Anaks and Billyo.txt
# Processed: Karmine Corp parts ways with MAGNUM.txt
# Processed: KOI starxo enters free agency.txt
# Processed: Kr1stal departs Xi Lai Gaming.txt
# Processed: KRÜ Esports stay alive with 2-0 over Bilibili.txt
# Processed: KRÜ talk on upsides to 2024 season despite early Champions exit in press conference.txt
# Processed: KRÜ to continue without heat.txt
# Processed: Leviatán allows Mazino to explore options.txt
# Processed: Leviatán coach Itopata concedes to issues against Trace in press conference.txt
# Processed: Leviatán defeat Talon Esports 2-0 to begin their Champions 2024 campaign.txt
# Processed: Leviatán overcome Team Vitality to claim playoff berth.txt
# Processed: LEVIATÁN summons Demon1.txt
# Processed: Leviátan sweep G2 in all-Americas rematch, advance to upper semis.txt
# Processed: Leviátan topple Team Heretics to secure upper finals.txt
# Processed: LOUD and Saadhak to part ways.txt
# Processed: M8 TaKaS to explore options for 2025.txt
# Processed: M80 parts ways with entire Valorant roster.txt
# Processed: MEDUSA and Anthem to explore options outside of DFM.txt
# Processed: Mini departs FNATIC.txt
# Processed: Moist x Shopify roster to explore options.txt
# Processed: MrFaliN pinpoints loss to EDG on micro mistakes in press conference.txt
# Processed: Munchkin acknowledges factors leading to upset loss against Heretics in press conference.txt
# Processed: NAVI allows Zyppan to explore options.txt
# Processed: nephh_ _Our performance wasn't up to standard_.txt
# Processed: NRG completes roster, signs mada, Verno, and bonkar.txt
# Processed: NRG releases Demon1.txt
# Processed: Oxygen Esports disbands Valorant roster.txt
# Processed: Paper Rex return to form in 2-0 against FUT.txt
# Processed: Patch 9.03 brings quality-of-life ability updates.txt
# Processed: pl1xx leaves Wolves Esports after one season.txt
# Processed: Riot announces changes to VCT Ascension Pacific.txt
# Processed: Riot announces finalized details for VCT Ascension Pacific.txt
# Processed: Riot announces VCT 2025 details.txt
# Processed: Riot removes BLEED from VCT Pacific, BOOM promoted.txt
# Processed: RRQ round off roster with Kush and Warbirds.txt
# Processed: runneR, Gorilla, temoc, Placido part with Team Vitality.txt
# Processed: Sacy announces retirement.txt
# Processed: Sayf keeps Vitality's spirits held high in press conference despite loss.txt
# Processed: Sayf speaks on key takeaways and lessons from 2024 in press conference.txt
# Processed: Secret part ways with NDG.txt
# Processed: Sentinels adds Reduxx as their sixth.txt
# Processed: Sentinels announce N4RRATE and bang.txt
# Processed: Sentinels eliminate FPX in dominant 2-0 sweep.txt
# Processed: Sentinels go the distance, eliminate FNATIC.txt
# Processed: Sentinels send DRX to lower bracket with 2-0 sweep.txt
# Processed: Sentinels survive group of death, eliminate Gen.G.txt
# Processed: sh1n to explore options outside of Karmine Corp.txt
# Processed: ShadoW becomes restricted free agent.txt
# Processed: sScary and LEGIJA announce free agency.txt
# Processed: SUYGETSU to explore options outside of NAVI.txt
# Processed: T1 adds BuZz.txt
# Processed: T1 parts ways with coach Daeda.txt
# Processed: T1 picks up Meteor.txt
# Processed: T1 signs Sylvan, Indigo, and CheongGak.txt
# Processed: t3xture reviews Gen.G's 2024 season in press conference.txt
# Processed: Talon Esports announces departures of Patiphan and b0i.txt
# Processed: Talon's FrosT hammers in on critical errors made against Leviatán in team press conference.txt
# Processed: Team Heretics beat Sentinels, will face Leviátan in lower finals.txt
# Processed: Team Heretics continue winstreak with 2-0 over FNATIC.txt
# Processed: Team Heretics exact revenge on Gen.G, qualify for quarterfinals.txt
# Processed: Team Heretics reach top four with 2-1 over DRX.txt
# Processed: Team Heretics topple Leviátan, advance to Champions 2024 grand final.txt
# Processed: Team Liquid announces kamo, LohaN, yaotziN.txt
# Processed: Team Liquid parts with head coach eMIL.txt
# Processed: Team Vitality sweep, eliminate Talon Esports.txt
# Processed: TenZ retires from competitive play.txt
# Processed: TenZ speaks on bouncing back heading into FPX matchup in press conference.txt
# Processed: TL Jamppi, Mistic, and Enzo enter restricted free agency.txt
# Processed: Toast speaks on Disguised reaching Ascension in year two.txt
# Processed: tomaszy announces restricted free agency.txt
# Processed: Trace Esports upset Leviatán to secure playoff spot at Champions 2024.txt
# Processed: Trace put China on the board at Champions.txt
# Processed: trexx_ _I thought the veto was very good for us_.txt
# Processed: Undefeated Sin Prisa Gaming wins Ascension Pacific.txt
# Processed: Valorant OFF__SEASON 2024 events announced.txt
# Processed: vanity's second Cloud9 stint comes to an end.txt
# Processed: VLR Rating 2.0 Update.txt
# Processed: Wolves Esports signs Lysoar and Fayde.txt
# Processed: Xi Lai Gaming lifts Ascension China.txt
# Processed: Zellsis pokes fun at haters following Gen.G elimination in press conference.txt
# Processed: Zellsis_ _We both know that he ain't gonna be yelling s--t_.txt
# Processed: ZETA DIVISION release hiroronn and yuran.txt
# Processed: ZETA Division’s Laz announces retirement.txt
# Processed: ZmjjKK reveals major shortcomings against G2 in press conference.txt
